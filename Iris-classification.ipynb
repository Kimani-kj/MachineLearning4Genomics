# %%
## IRIS CLASSIFICATION

from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split # splits the data into training and testing datasets
import pandas as pd

# %%
iris = load_iris()

# %%
iris_df = pd.DataFrame(iris['data'], columns=iris['feature_names'])

# %%
iris_df['Species'] = iris['target']

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Species
# 0          0
# ...

# %%
from matplotlib import pyplot as plt
iris_df.plot(kind='scatter', x='sepal length (cm)', y='sepal width (cm)',
             s=32, alpha=.8, c=iris.target, cmap='viridis')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
iris_df.plot(kind='scatter', x='sepal length (cm)', y='petal width (cm)',
             s=32, alpha=.8, c=iris.target, cmap='viridis')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
iris_df.plot(kind='scatter', x='petal length (cm)', y='petal width (cm)',
             s=32, alpha=.8, c=iris.target, cmap='viridis')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
iris_df.plot(kind='scatter', x='petal length (cm)', y='sepal width (cm)',
             s=32, alpha=.8, c=iris.target, cmap='viridis')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target)
knn_model = KNeighborsClassifier()

# %%
## For reprodubility
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, random_state=6)
knn_model = KNeighborsClassifier()

# %%
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (112, 4)
# (38, 4)

# %%
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
print("The accuracy on the test data:", knn_model.score(X_test, y_test))
# Out:
# The accuracy on the test data: 0.9210526315789473

# %%
print("The accuracy on the test data:", 100*knn_model.score(X_test, y_test))
# Out:
# The accuracy on the test data: 92.10526315789474

# %%
print("The accuracy on the training data:", 100*knn_model.score(X_train, y_train))
# Out:
# The accuracy on the training data: 99.10714285714286

# %%
#When the perfomance on the training data is better than on the test data, the model is overfitting.
#When the perfomance on the test data is better than on the training data, the model is generalising well (as long as both perfomances are pretty good).
#When both the perfomances on both the training and test data is poor, the model is underfitting.
