# %%
# Iris classification

# %%
##loadinf a dataset from SCikit learn
from sklearn.datasets import load_iris

# %%
##loading an algorithim for the data
from sklearn.neighbors import KNeighborsClassifier

# %%
##loading the split that splits data 80% training and 20% testing 
from sklearn.model_selection import train_test_split

# %%
import pandas as pd

# %%
iris = load_iris()

# %%
iris_df = pd.DataFrame(iris['data'], columns=iris['feature_names'])

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
iris_df['species']= iris['target']

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
##to generate the entire table
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      species
# 0          0
# ...

# %%
##visualizing the plots
from matplotlib import pyplot as  plt
iris_df.plot(kind='scatter',x='sepal length (cm)', y='petal width (cm)',
            s=32 , alpha=8, )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 3
#       1 ##visualizing the plots
#       2 from matplotlib import pyplot as  plt
# ----> 3 iris_df.plot(kind='scatter',x='sepal length (cm)', y='petal width (cm)',
#       4             s=32 , alpha=8)
#
# File ~/miniforge3/envs/Eneza/lib/python3.12/site-packages/pandas/plotting/_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     973 if kind in self._dataframe_kinds:
#     974     if isinstance(data, ABCDataFrame):
# --> 975         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     976     else:
#     977         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# File ~/miniforge3/envs/Eneza/lib/python3.12/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
# ...

# %%
x_train, x_test, y_train, y_test= train_test_split(iris.data, iris.target, random_state=6)#this makes it reproducible
knm_model=KNeighborsClassifier()

# %%
x_train.shape
# Out:
# (112, 4)

# %%
##creating a model
knm_model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
##calculating the accuracy
print('The accuracy on the test data', round(100* knm_model.score(x_test, y_test), 2),"%")
# Out:
# The accuracy on the test data 97.37 %

# %%
print('The accuracy on the training data', round(100* knm_model.score(x_train, y_train), 2),"%")
# Out:
# The accuracy on the training data 98.21 %

# %%
'''## when ther performance of the training is better than on the test data the model is overfitting. 
   ##when the operdormance on the test data is beter tna the trainning data the model is 
    generalising well(as long as both performance are pretty good)
   ## when the performance of both trainig and test are poor the mode is underfitting'''
